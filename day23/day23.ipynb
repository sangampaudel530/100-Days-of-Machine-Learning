# %% [markdown]
# ### Feature Scaling Standardization

# %% [markdown]
# # 🚀 100 Days of Machine Learning Journey
#
# > **Transforming Data into Intelligence - One Day at a Time**
#
# [![Python](https://img.shields.io/badge/Python-3.8+-blue.svg)](https://python.org)
# [![Jupyter](https://img.shields.io/badge/Jupyter-Notebook-orange.svg)](https://jupyter.org)
# [![scikit-learn](https://img.shields.io/badge/scikit--learn-Latest-green.svg)](https://scikit-learn.org)
# [![Progress](https://img.shields.io/badge/Progress-37%2F100-brightgreen.svg)](https://github.com/yourusername/100-days-of-ml)
#
# ---
#
# ## 📊 **Journey Overview**
#
# This repository chronicles my comprehensive 100-day Machine Learning expedition, following the expertly crafted curriculum from **CampusX YouTube channel**. Each day represents a step forward in mastering the art and science of Machine Learning.
#
# ### **🎯 Current Progress: Day 37/100**
#
# **🔥 Latest Milestone:** Advanced preprocessing techniques and missing data handling strategies
#
# ---
#
# ## 🛠 **Tech Arsenal**

# %%
# Core Data Science Stack
pandas • numpy • matplotlib • seaborn • scipy
scikit-learn • jupyter • beautifulsoup4

# %%
# Clone the journey
git clone https://github.com/yourusername/100-days-of-ml.git
cd 100-days-of-ml

# Install the ML toolkit
pip install pandas numpy matplotlib seaborn scikit-learn jupyter

# Start exploring
cd day37
jupyter notebook day37.ipynb

# %% [markdown]
# ---
#
# ## 📁 **Repository Structure**

# %%
100_days_of_ml/
├── day18/                 # Web Scraping ESPN
├── day19/                 # Statistical Analysis
├── day21/                 # Iris EDA
├── day22/                 # Pandas Profiling
├── day23/                 # Standard Scaling
├── day24/                 # Min-Max Scaling (Wine)
├── day25/                 # Min-Max Advanced
├── day26/                 # Ordinal Encoding
├── day27/                 # One-Hot Encoding
├── day28/                 # Column Transformers
├── day29/                 # ML Pipelines
├── day30/                 # Function Transformers ⭐
├── day31/                 # Power Transformers
├── day32/                 # Binning & Discretization
├── day33/                 # Mixed Variables
├── day34/                 # Date-Time Features
├── day35/                 # Complete Case Analysis
├── day36/                 # Numerical Imputation
├── day37/                 # Categorical Imputation
├── day38/                 # Random Sample Imputation (WIP)
└── ...                    # Journey continues...

# %% [markdown]
# ---
#
# ## 🏆 **Milestones & Progress**
#
# | **Phase** | **Days** | **Focus Area** | **Status** | **Completion** |
# |-----------|----------|----------------|------------|----------------|
# | **Foundation** | 18-22 | EDA & Statistics | ✅ Complete | 100% |
# | **Preprocessing** | 23-38 | Feature Engineering | 🚧 In Progress | 94% |
# | **Classification** | 39-65 | Supervised Learning | ⏳ Next | 0% |
# | **Regression** | 66-75 | Prediction Models | ⏳ Upcoming | 0% |
# | **Unsupervised** | 76-85 | Pattern Discovery | ⏳ Upcoming | 0% |
# | **Advanced** | 86-95 | Deep Learning & MLOps | ⏳ Upcoming | 0% |
# | **Capstone** | 96-100 | Real Projects | ⏳ Final | 0% |
#
# ---
#
# ## 🎓 **Learning Philosophy**
#
# > *"Every expert was once a beginner. Every pro was once an amateur."*
#
# ### **Daily Learning Framework:**
# 1. **🎯 Theory First** - Understanding the mathematical foundations
# 2. **💻 Code Along** - Hands-on implementation with real datasets
# 3. **🔬 Experiment** - Testing variations and edge cases
# 4. **📝 Document** - Recording insights and lessons learned
# 5. **🚀 Apply** - Solving real-world problems
#
# ---
#
# ## 🙏 **Heartfelt Acknowledgments**
#
# ### **🌟 Primary Mentor**
# **Massive gratitude to [Nitish Singh Sir](https://www.youtube.com/@campusx-official) and the entire CampusX team for creating world-class, FREE educational content. Their structured approach and practical focus have made this transformative journey possible.**
#
# ### **What Makes CampusX Exceptional:**
# - 📚 **Structured Curriculum** - Perfect learning progression
# - 🎯 **Practical Focus** - Real datasets and industry scenarios
# - 💡 **Clear Teaching** - Complex concepts made simple
# - 🔧 **Hands-on Approach** - Code-along methodology
# - 🆓 **Accessible Education** - High-quality content for everyone
# - 👨‍🏫 **Expert Guidance** - Industry experience translated to education
#
# ---
#
# ## 📈 **What's Next?**
#
# ### **Immediate Goals (Days 38-42):**
# - Complete advanced imputation techniques
# - Master KNN and multivariate imputation
# - Begin feature selection methodologies
# - Implement automated feature engineering
#
# ### **Short-term Vision (Days 43-65):**
# - Dominate supervised learning algorithms
# - Build production-ready classification models
# - Master model evaluation and selection
# - Develop ensemble learning expertise
#
# ### **Long-term Mission (Days 66-100):**
# - Become proficient in all ML domains
# - Create end-to-end deployable systems
# - Build a compelling ML portfolio
# - Transition into ML/Data Science role
#
# ---
#
# ## 💫 **Join the Journey**
#
# ⭐ **Star** if this journey inspires your ML adventure
# 🍴 **Fork** to create your own learning path
# 💬 **Share** your progress and insights
# 🤝 **Connect** with fellow ML enthusiasts
#
# ---
#
# ## 📊 **Impact Metrics**
#
# - **📈 Skills Growth**: 37 days of continuous learning
# - **💻 Code Written**: 37+ Jupyter notebooks with hands-on implementations
# - **📚 Concepts Mastered**: 50+ ML preprocessing techniques
# - **🎯 Projects Completed**: 15+ real-world dataset analyses
# - **🔗 Pipelines Built**: End-to-end ML workflows
# - **🌍 Community Impact**: Sharing knowledge for others to learn
#
# ---
#
# **🔥 37 Days Down, 63 Days of ML Magic Ahead! 🔥**
#
# *"The best investment you can make is in yourself. The best time to start was yesterday. The second best time is now."*
#
# ---
#
# **Next Stop:** Day 38 - Random Sample Imputation Mastery
# **Destination:** Day 100 - Production-Ready ML Engineer
#
# **Let's turn data into intelligence, one day at a time! 🚀✨**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Social_Network_Ads.csv')

# %%
df.sample(5)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 89   15682268    Male   35            50000          0
# 269  15583137    Male   40            61000          0
# 173  15581654  Female   34            43000          0
# 378  15577806    Male   41            87000          1
# 157  15602373    Male   29            75000          0

# %%
df=df.iloc[:,2:]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 166   22            55000          0
# 154   40            47000          0
# 272   60            42000          1
# 5     27            58000          0
# 143   30            89000          0

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.2,random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((320, 2), (80, 2))

# %%
X_train.head()
# Out:
#      Age  EstimatedSalary
# 336   58           144000
# 64    59            83000
# 55    24            55000
# 106   26            35000
# 300   58            38000

# %%
X_test.head()
# Out:
#      Age  EstimatedSalary
# 132   30            87000
# 309   38            50000
# 341   35            75000
# 196   30            79000
# 246   35            50000

# %% [markdown]
# ## using StandardScaler

# %%
#importing standarad scaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaler.mean_
# Out:
# array([3.8218750e+01, 6.9928125e+04])

# %%
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.92295008e+00,  2.14601566e+00],
#        [ 2.02016082e+00,  3.78719297e-01],
#        [-1.38221530e+00, -4.32498705e-01],
#        [-1.18779381e+00, -1.01194013e+00],
#        [ 1.92295008e+00, -9.25023920e-01],
#        [ 3.67578135e-01,  2.91803083e-01],
#        [ 1.73156642e-01,  1.46942725e-01],
#        [ 2.02016082e+00,  1.74040666e+00],
#        [ 7.56421121e-01, -8.38107706e-01],
#        [ 2.70367388e-01, -2.87638347e-01],
#        [ 3.67578135e-01, -1.71750061e-01],
#        [-1.18475597e-01,  2.20395980e+00],
#        [-1.47942605e+00, -6.35303205e-01],
#        [-1.28500455e+00, -1.06988428e+00],
#        [-1.38221530e+00,  4.07691369e-01],
#        [-1.09058306e+00,  7.55356227e-01],
#        [-1.47942605e+00, -2.00722133e-01],
#        [ 9.50842613e-01, -1.06988428e+00],
#        [ 9.50842613e-01,  5.81523798e-01],
#        [ 3.67578135e-01,  9.87132798e-01],
#        [ 5.61999628e-01, -8.96051849e-01],
#        [-6.04529329e-01,  1.45068594e+00],
# ...

# %%
X_test_scaled
# Out:
# array([[-7.98950822e-01,  4.94607583e-01],
#        [-2.12648508e-02, -5.77359062e-01],
#        [-3.12897090e-01,  1.46942725e-01],
#        [-7.98950822e-01,  2.62831011e-01],
#        [-3.12897090e-01, -5.77359062e-01],
#        [-1.09058306e+00, -1.44652121e+00],
#        [-7.01740076e-01, -1.59138156e+00],
#        [-2.15686344e-01,  2.14601566e+00],
#        [-1.96547978e+00, -5.58617754e-02],
#        [ 8.53631867e-01, -7.80163563e-01],
#        [-7.98950822e-01, -6.06331134e-01],
#        [-9.93372315e-01, -4.32498705e-01],
#        [-1.18475597e-01, -4.32498705e-01],
#        [ 7.59458956e-02,  2.04886868e-01],
#        [-1.77105829e+00,  4.65635512e-01],
#        [-6.04529329e-01,  1.36376973e+00],
#        [-1.18475597e-01,  2.04886868e-01],
#        [-1.86826903e+00,  4.36663440e-01],
#        [ 1.63131784e+00,  1.74040666e+00],
#        [-3.12897090e-01, -1.38857706e+00],
#        [-3.12897090e-01, -6.64275277e-01],
#        [ 8.53631867e-01,  2.14601566e+00],
# ...

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean    38.2          69928.1
# std     10.3          34570.1
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     38.0          69500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  320.0            320.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -2.0             -1.6
# 25%     -0.8             -0.8
# 50%     -0.0             -0.0
# 75%      0.8              0.5
# max      2.1              2.3

# %% [markdown]
# ## Effect of the scaling

# %%
fig, (ax1, ax2)= plt.subplots(ncols=2, figsize=(12,5))
ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'],X_train_scaled["EstimatedSalary"],color='red')
ax2.set_title("After Scaling")
# Out:
# Text(0.5, 1.0, 'After Scaling')

# %%
fig, (ax1,ax2)= plt.subplots(ncols=2, figsize=(12,5))
ax1.set_title("Before Scaling")
sns.kdeplot(X_train['Age'],ax=ax1)
sns.kdeplot(X_train['EstimatedSalary'],ax=ax1)

ax2.set_title("After Scaling")
sns.kdeplot(X_train_scaled['Age'],ax=ax2)
sns.kdeplot(X_train_scaled['EstimatedSalary'],ax=ax2)
# Out:
# <Axes: title={'center': 'After Scaling'}, xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## distrubution before and after scaling

# %%
fig, (ax1,ax2)=plt.subplots(ncols=2, figsize=(12,5))
ax1.set_title("Before Scaling")
ax2.set_title("After Scaling")
sns.kdeplot(X_train['Age'],ax=ax1, fill=True)
sns.kdeplot(X_train_scaled['Age'],ax=ax2,fill=True)
# Out:
# <Axes: title={'center': 'After Scaling'}, xlabel='Age', ylabel='Density'>

# %% [markdown]
# - not any change in distribution or shape by the scaling .
# - scaling mainly centered the data and scale it by std factor

# %% [markdown]
# ## practical impact of scaling

# %%
from sklearn.linear_model import LogisticRegression 
model=LogisticRegression()
model_scaled=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred_scaled=model_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Accuracy without scaling: ", accuracy_score(y_test,y_pred))
print("Accuracy with scaling: ", accuracy_score(y_test, y_pred_scaled))
# Out:
# Accuracy without scaling:  0.9125
# Accuracy with scaling:  0.925
